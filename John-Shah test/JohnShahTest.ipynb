# %%
using Pkg
Pkg.activate("../Dynamic_brittle_fracture")
Pkg.instantiate()
Pkg.status()
# Out:
#   Activating project at `~/Library/CloudStorage/OneDrive-IndianInstituteofTechnologyBhubaneswar/Dynamic-Fracture/Dynamic_brittle_fracture`
# Status `~/Library/CloudStorage/OneDrive-IndianInstituteofTechnologyBhubaneswar/Dynamic-Fracture/Dynamic_brittle_fracture/Project.toml`
#   [705231aa] Gmsh v0.2.2
#   [56d4f2e9] Gridap v0.17.16
#   [3025c34a] GridapGmsh v0.6.1
#   [7073ff75] IJulia v1.24.0
#   [91a5bcdd] Plots v1.38.5
#   [37e2e46d] LinearAlgebra

# %%
using GridapGmsh
using Gmsh: gmsh
using Gridap
using Gridap.Geometry
using Gridap.TensorValues
using Plots
using LinearAlgebra

# %%
I2 = one(TensorValue{2,2,Float64})
I4_sym = one(SymFourthOrderTensorValue{2,Float64})
I4_vol = (1.0/2)*I4_sym
I4_dev = I4_sym - I4_vol
# Out:
# SymFourthOrderTensorValue{2, Float64, 9}(0.5, 0.0, 0.0, 0.0, 0.25, 0.0, 0.0, 0.0, 0.5)

# %%
const ls = 0.8
# Out:
# 0.8

# %%
const L = 228
const H = 76.2
const γₜ = 0.77
const γ = 0.6 # [0.82, 0.6]
const L1 = 101.6
const L2 = γ*L1
const CP = 19.4 # crack height
const CL = (L/2)-L2 # crack location along length direction
const CH = L/1000
const hfc = ls/50
const hf = ls/2.1
const h = 3*hf
const FMR = 5*ls

gmsh.initialize()
gmsh.option.setNumber("General.Terminal", 1)
p1 = gmsh.model.geo.addPoint(0.0, 0.0, 0.0, h)
p2 = gmsh.model.geo.addPoint((L/2)-L1-h, 0.0, 0.0, h)
p3 = gmsh.model.geo.addPoint((L/2)-L1+h, 0.0, 0.0, h)
p4 = gmsh.model.geo.addPoint(CL-CH, 0.0, 0.0, hf) 
p5 = gmsh.model.geo.addPoint(CL-CH, CP, 0.0, hfc) 
p6 = gmsh.model.geo.addPoint(CL+CH, CP, 0.0, hfc) 
p7 = gmsh.model.geo.addPoint(CL+CH, 0.0, 0.0, hf)
p8 = gmsh.model.geo.addPoint((L/2)+L1-h, 0.0, 0.0, h)
p9 = gmsh.model.geo.addPoint((L/2)+L1+h,0.0, 0.0, h)
p10 = gmsh.model.geo.addPoint(L, 0, 0.0, h)
p11 = gmsh.model.geo.addPoint(L, H, 0.0, h)
p12 = gmsh.model.geo.addPoint((L/2)+2*h, H, 0.0, hf)
p13 = gmsh.model.geo.addPoint((L/2)-2*h, H, 0.0, hf)
p14 = gmsh.model.geo.addPoint(0, H, 0.0, h)

l1 = gmsh.model.geo.addLine(p1, p2)
l2 = gmsh.model.geo.addLine(p2, p3)
l3 = gmsh.model.geo.addLine(p3, p4)
l4 = gmsh.model.geo.addLine(p4, p5)
l5 = gmsh.model.geo.addLine(p5, p6)
l6 = gmsh.model.geo.addLine(p6, p7)
l7 = gmsh.model.geo.addLine(p7, p8)
l8 = gmsh.model.geo.addLine(p8, p9)
l9 = gmsh.model.geo.addLine(p9, p10)
l10 = gmsh.model.geo.addLine(p10, p11)
l11 = gmsh.model.geo.addLine(p11, p12)
l12 = gmsh.model.geo.addLine(p12, p13)
l13 = gmsh.model.geo.addLine(p13, p14)
l14 = gmsh.model.geo.addLine(p14, p1)

cl = gmsh.model.geo.addCurveLoop([l1,l2,l3,l4,l5,l6,l7,l8,l9,l10,l11,l12,l13,l14])
ps = gmsh.model.geo.addPlaneSurface([cl])
pg1 = gmsh.model.addPhysicalGroup(2, [ps])
pg2 = gmsh.model.addPhysicalGroup(1, [l2]) 
pg3 = gmsh.model.addPhysicalGroup(1,[l8])
pg4 = gmsh.model.addPhysicalGroup(1,[l12])

gmsh.model.setPhysicalName(2, pg1, "Domain")
gmsh.model.setPhysicalName(1, pg2, "LeftSupp")
gmsh.model.setPhysicalName(1, pg3, "RightSupp")
gmsh.model.setPhysicalName(1, pg4, "LoadLine")

p15 = gmsh.model.geo.addPoint(L/2, H, 0.0, hf)
p16 = gmsh.model.geo.addPoint(L/2, 0.0, 0.0, hf)
l16 = gmsh.model.geo.addLine(p6, p15)
l17 = gmsh.model.geo.addLine(p15, p16)

gmsh.model.mesh.field.add("Distance", 1)
gmsh.model.mesh.field.setNumbers(1, "EdgesList", [l16,l17])

gmsh.model.mesh.field.add("Threshold", 2)
gmsh.model.mesh.field.setNumber(2, "IField", 1)
gmsh.model.mesh.field.setNumber(2, "LcMin", hf)
gmsh.model.mesh.field.setNumber(2, "LcMax", h)
gmsh.model.mesh.field.setNumber(2, "DistMin", 0.15*H)
gmsh.model.mesh.field.setNumber(2, "DistMax", 0.2*H)

gmsh.model.mesh.field.setAsBackgroundMesh(2)

gmsh.model.geo.synchronize()
gmsh.model.mesh.generate(2)
gmsh.write("JohnShah.msh")
gmsh.finalize()
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 20%] Meshing curve 4 (Line)
# Info    : [ 30%] Meshing curve 5 (Line)
# Info    : [ 40%] Meshing curve 6 (Line)
# Info    : [ 40%] Meshing curve 7 (Line)
# Info    : [ 50%] Meshing curve 8 (Line)
# Info    : [ 50%] Meshing curve 9 (Line)
# Info    : [ 60%] Meshing curve 10 (Line)
# Info    : [ 70%] Meshing curve 11 (Line)
# Info    : [ 70%] Meshing curve 12 (Line)
# Info    : [ 80%] Meshing curve 13 (Line)
# Info    : [ 90%] Meshing curve 14 (Line)
# Info    : [ 90%] Meshing curve 15 (Line)
# Info    : [100%] Meshing curve 16 (Line)
# Info    : Done meshing 1D (Wall 0.0193673s, CPU 0.01914s)
# Info    : Meshing 2D...
# Info    : Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 1.31855s, CPU 1.30208s)
# Info    : 78440 nodes 155970 elements
# Info    : Writing 'JohnShah.msh'...
# Info    : Done writing 'JohnShah.msh'
# Warning : Unknown entity of dimension 2 and tag 1 in physical group 1
# Warning : Unknown entity of dimension 1 and tag 2 in physical group 2
# Warning : Unknown entity of dimension 1 and tag 8 in physical group 3
# Warning : Unknown entity of dimension 1 and tag 12 in physical group 4

# %%
model = GmshDiscreteModel("JohnShah.msh")
writevtk(model ,"JohnShah")
# Out:
# Info    : Reading 'JohnShah.msh'...
# Info    : 33 entities
# Info    : 77516 nodes
# Info    : 153865 elements
# Info    : [ 10%] Reading elements
# Info    : [ 20%] Reading elements
# Info    : [ 20%] Reading elements
# Info    : [ 30%] Reading elements
# Info    : [ 40%] Reading elements
# Info    : [ 40%] Reading elements
# Info    : [ 50%] Reading elements
# Info    : [ 60%] Reading elements
# Info    : [ 60%] Reading elements
# Info    : [ 70%] Reading elements
# Info    : [ 80%] Reading elements
# Info    : [ 80%] Reading elements
# Info    : [ 90%] Reading elements
# Info    : [100%] Reading elements
#
# Info    : Done reading 'JohnShah.msh'
# 3-element Vector{Vector{String}}:
#  ["JohnShah_0.vtu"]
#  ["JohnShah_1.vtu"]
#  ["JohnShah_2.vtu"]

# %%
const E_mat = 31.37*1e3 
const ν_mat = 0.2   
const ρ = 2400*1e-9

G₁₂_mat = E_mat/(2*(1+ν_mat))
const μ = G₁₂_mat
const λ = (E_mat*ν_mat)/((1+ν_mat)*(1-2*ν_mat))
const k = λ + μ

J = 0.0
# Out:
# 0.0

# %%
const Gc = 31.1*1e-3 
const η = 1e-15
# Out:
# 1.0e-15

# %%
function ElasFourthOrderConstTensor(E₁,E₂,ν₁₂,ν₂₁,G₁₂,PlanarState)
    # 1 for Plane Stress and 2 Plane Strain Condition 
  if PlanarState == 1
      C1111 = E₁/(1-ν₁₂*ν₂₁)
      C1122 = (ν₂₁*E₁)/(1-ν₁₂*ν₂₁)
      C1112 = 0.0
      C2222 = E₂/(1-ν₁₂*ν₂₁)
      C2212 = 0.0
      C1212 = G₁₂     
  elseif PlanarState == 2
      C1111 = (E₁*(1-ν₁₂*ν₂₁))/((1+ν₁₂)*(1-ν₁₂-2*ν₁₂*ν₂₁))
      C1122 = (ν₂₁*E₁)/(1-ν₁₂-2*ν₁₂*ν₂₁)
      C1112 = 0.0
      C2222 = (E₂*(1-ν₁₂))/(1-ν₁₂-2*ν₁₂*ν₂₁)
      C2212 = 0.0
      C1212 = G₁₂ 
  end
  C_ten = SymFourthOrderTensorValue(C1111,C1112,C1122,C1112,C1212,C2212,C1122,C2212,C2222)
    return  C_ten
end
const C_mat = ElasFourthOrderConstTensor(E_mat,E_mat,ν_mat,ν_mat,G₁₂_mat,2)
# Out:
# SymFourthOrderTensorValue{2, Float64, 9}(34855.555555555555, 0.0, 8713.888888888889, 0.0, 13070.833333333334, 0.0, 8713.888888888889, 0.0, 34855.555555555555)

# %%
### Spectral

function σ_mod(ε, ε_in, s_in)
            σM = (s_in^2 + η)*(λ*tr(ε)*one(ε) + 2*μ*(ε))
    return σM
end
# Out:
# σ_mod (generic function with 1 method)

# %%
### Spectral

function Eigen(ε)
    εArray = get_array(ε)
    Λ, P = eigen(εArray)
    ε1 = Λ[1]
    ε2 = Λ[2]
    if ε1 >= 0 &&  ε2 >= 0
        Λpos = [ε1 0; 0 ε2]
        Λneg = [0 0; 0 0]
    elseif ε1 >= 0 &&  ε2 < 0
        Λpos = [ε1 0; 0 0]
        Λneg = [0 0; 0 ε2]
    elseif ε1 < 0 &&  ε2 >= 0
        Λpos = [0 0; 0 ε2]
        Λneg = [ε1 0; 0 0]
    elseif ε1 < 0 &&  ε2 < 0
        Λpos = [0 0; 0 0]
        Λneg = [ε1 0; 0 ε2]
    end 
   εPos = P*Λpos*P'
   εNeg = P*Λneg*P'
   EpPos = TensorValue(εPos)
   EpNeg = TensorValue(εNeg)    
    return  EpPos, EpNeg
end
# Out:
# Eigen (generic function with 1 method)

# %%
### Spectral

function ψPos(ε_in)
    ϵ_Pos, ϵ_Neg = Eigen(ε_in)
    if tr(ε_in) >= 0
        ψPlus = 0.5*λ*(tr(ε_in))^2 + μ*(ϵ_Pos ⊙ ϵ_Pos) 
    elseif tr(ε_in) < 0
        ψPlus = μ*(ϵ_Pos ⊙ ϵ_Pos)
    end
    return ψPlus
end
# Out:
# ψPos (generic function with 1 method)

# %%
function new_EnergyState(ψPlusPrev_in,ψhPos_in)
  ψPlus_in = ψhPos_in
  if ψPlus_in >= ψPlusPrev_in
    ψPlus_out = ψPlus_in
  else
    ψPlus_out = ψPlusPrev_in
  end
  true,ψPlus_out
end
# Out:
# new_EnergyState (generic function with 1 method)

# %%
function project(q,model,dΩ,order)
  reffe = ReferenceFE(lagrangian,Float64,order)
  V = FESpace(model,reffe,conformity=:L2)
  a(u,v) = ∫( u*v )*dΩ
  l(v) = ∫( v*q )*dΩ
  op = AffineFEOperator(a,l,V,V)
  qh = solve(op)
  qh
end
# Out:
# project (generic function with 1 method)

# %%
order = 1
degree = 2*order
# Out:
# 2

# %%
Ω = Triangulation(model)
dΩ = Measure(Ω,degree)
# Out:
# Measure()

# %%
labels = get_face_labeling(model)
LoadTagId = get_tag_from_name(labels,"LoadLine")
Γ_Load = BoundaryTriangulation(model,tags = LoadTagId)
dΓ_Load = Measure(Γ_Load,degree)
n_Γ_Load = get_normal_vector(Γ_Load)
# Out:
# GenericCellField():
#  num_cells: 12
#  DomainStyle: ReferenceDomain()
#  Triangulation: BoundaryTriangulation()
#  Triangulation id: 15444857804460819950

# %%
reffe_PF = ReferenceFE(lagrangian,Float64,order)
V0_PF = TestFESpace(model,reffe_PF;
  conformity=:H1)
U_PF = TrialFESpace(V0_PF)
# Out:
# UnconstrainedFESpace()

# %%
reffe_Disp = ReferenceFE(lagrangian,VectorValue{2,Float64},order)
        V0_Disp = TestFESpace(model,reffe_Disp;
          conformity=:H1,
          dirichlet_tags=["LeftSupp","LoadLine","RightSupp"],
          dirichlet_masks=[(true,true), (false,true),(false,true)])

uh = uh₈ = uh₉ = uh₁₀ = vh = ah = zero(V0_Disp)
initial_value = zero(V0_Disp)
# Out:
# SingleFieldFEFunction():
#  num_cells: 153849
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 17331572075022438990

# %%
function  stepPhaseField(uh_in,ψPlusPrev_in)
        
        a_PF(s,ϕ) = ∫( Gc*ls*∇(ϕ)⋅ ∇(s) + 2*ψPlusPrev_in*s*ϕ + (Gc/ls)*s*ϕ )*dΩ
        b_PF(ϕ) = ∫( (Gc/ls)*ϕ )*dΩ
        op_PF = AffineFEOperator(a_PF,b_PF,U_PF,V0_PF)
        sh_out = solve(op_PF)           
    
    return sh_out
    
end
# Out:
# stepPhaseField (generic function with 1 method)

# %%
function   stepDisp(uh_in, sh_in, count, time, T1, dt, v₀, uh, vh, ah)
        
        function uapp(x,t, time,T1, v₀)
           if time<=T1
              return VectorValue(0.0,-1.0)*((v₀/(2*T1))*t^2)
           else
              return VectorValue(0.0,-1.0)*((v₀*t) - (v₀*T1/2))
           end
        end
        u(x,t) = uapp(x,t, time,T1, v₀)
        g(x,t) = VectorValue(x[1]*0,x[2]*0)*t
        g(t::Real) = x-> g(x,t)
        u(t::Real) = x -> u(x,t)
    
        t0 = time-dt
        tF = time  
        Δt = dt/10
    
        U_Disp = TransientTrialFESpace(V0_Disp,[g,u,g])

        f(t) = VectorValue(0.0,0.0)
        m(utt,w) = ρ*∫(utt⋅w)dΩ
        c(ut,w) = ∫(ut⋅w)dΩ
            
        a_Disp(u,w) = ∫( (ε(w) ⊙ (σ_mod∘(ε(u),ε(uh_in),sh_in)) ) )*dΩ
        b_Disp(w,t) = ∫(w⋅f(t))dΩ
    
        res(t,u,w) = m(∂tt(u),w) + a_Disp(u,w) - b_Disp(w,t)
        jac(t,u,du,w) = a_Disp(du,w)
        jac_t(t,u,dut,w) = c(dut,w)
        jac_tt(t,u,dutt,w) = m(dutt,w)

        op = TransientFEOperator(res,jac,jac_t,jac_tt,U_Disp,V0_Disp)
    
        γ = 0.5
        β = 0.25

        U0 = U_Disp(t0)
        uh0 = interpolate_everywhere(uh,U0)
        vh0 = interpolate_everywhere(vh,U0)
        ah0 = interpolate_everywhere(ah,U0)

        Ls = LUSolver()
        ode_solver = Newmark(Ls,Δt,γ,β)

       sol_t = solve(ode_solver,op,(uh0,vh0,ah0),t0,tF) 
       
       counter = 0
        
       vApp =  u([L/2,H],time)[2]

       for (uₕ,t) in sol_t
          counter = counter + 1
          if counter == 8
            copyto!(uh₈.free_values, copy(uₕ.free_values))
            copyto!(uh₈.dirichlet_values, copy(uₕ.dirichlet_values))
          elseif counter == 9
            copyto!(uh₉.free_values, copy(uₕ.free_values)) 
            copyto!(uh₉.dirichlet_values, copy(uₕ.dirichlet_values))  
          elseif counter == 10
            copyto!(uh₁₀.free_values, copy(uₕ.free_values))
            copyto!(uh₁₀.dirichlet_values, copy(uₕ.dirichlet_values))
            print(" 👍 Doing at time $t") 
          end
       end  
      
       return (vApp, uh₈, uh₉, uh₁₀)
         
    end
# Out:
# stepDisp (generic function with 1 method)

# %%
tApp = 0
vApp = 0.0
v₀ = 60e-6
innerMax = 16
cnt = 0
dt1 =  4
Tmax = 2800
T1 = 196

Load = Float64[]
Displacement = Float64[]

push!(Load, 0.0)
push!(Displacement, 0.0)

sPrev = CellState(1.0,dΩ)
sh = project(sPrev,model,dΩ,order)
ψPlusPrev = CellState(0.0,dΩ)
# Out:
# CellState():
#  num_cells: 153849
#  DomainStyle: ReferenceDomain()
#  Triangulation: BodyFittedTriangulation()
#  Triangulation id: 17331572075022438990

# %%
while tApp .< Tmax 
    
    if tApp.<=T1 
        dt = dt1
    else
        dt = dt1*10
    end
    
    cnt = cnt .+ 1    
    tApp = tApp + dt
    
    print("\n Entering time step$cnt:", float(tApp))
    
    
   for inner = 1:innerMax
        
        ψhPlusPrev = project(ψPlusPrev,model,dΩ,order)
        
        RelErr = abs(sum(∫( Gc*ls*∇(sh)⋅ ∇(sh) + 2*ψhPlusPrev*sh*sh + (Gc/ls)*sh*sh)*dΩ-∫( (Gc/ls)*sh)*dΩ))/abs(sum(∫( (Gc/ls)*sh)*dΩ))
        print("\n Relative error = ",float(RelErr))
        
        sh = stepPhaseField(uh,ψhPlusPrev) 
        Δt = dt/10

        if cnt == 1
           global vApp, uh8, uh9, uh = stepDisp(uh, sh, cnt, tApp, T1, dt, v₀, initial_value, initial_value, initial_value)
           global vh9 = (uh9 - uh8)/Δt
           global vh = (uh - uh9)/Δt
           global ah = (vh - vh9)/Δt
        else
           global vApp, uh8, uh9, uh = stepDisp(uh, sh, cnt, tApp, T1, dt, v₀, uh, vh, ah)
           global vh9 = (uh9 - uh8)/Δt
           global vh = (uh - uh9)/Δt
           global ah = (vh - vh9)/Δt
        end

        ψhPos_in = ψPos∘(ε(uh))    
        update_state!(new_EnergyState,ψPlusPrev,ψhPos_in)
        
        if  RelErr < 1e-8
            break 
        end      
    end
    
    Node_Force = sum(∫( n_Γ_Load ⋅ (σ_mod∘(ε(uh),ε(uh),sh)) ) *dΓ_Load)
    push!(Load, -Node_Force[2])
    push!(Displacement, -vApp)
 
        writevtk(Ω,"results_JohnShah$cnt",cellfields=
         ["uh"=>uh,"s"=>sh , "epsi"=>ε(uh),"sigma"=>σ_mod∘(ε(uh),ε(uh),sh)])
end
# Out:
#  Entering time step1:4.0
#  Relative error = 4.5348267765102473e-17 👍 Doing at time 3.9999999999999996
#  Entering time step2:8.0
#  Relative error = 6.874230893547582e-12 👍 Doing at time 8.000000000000004
#  Entering time step3:12.0
#  Relative error = 1.0311619201592447e-10 👍 Doing at time 12.000000000000004
#  Entering time step4:16.0
#  Relative error = 4.468374221732247e-10 👍 Doing at time 16.000000000000004
#  Entering time step5:20.0
#  Relative error = 1.203024216950322e-9 👍 Doing at time 19.999999999999986
#  Entering time step6:24.0
#  Relative error = 2.5366627492278106e-9 👍 Doing at time 23.999999999999986
#  Entering time step7:28.0
#  Relative error = 4.612738890184466e-9 👍 Doing at time 27.999999999999986
#  Entering time step8:32.0
#  Relative error = 7.5962378411237e-9 👍 Doing at time 31.999999999999986
#  Entering time step9:36.0
#  Relative error = 1.1652143559527393e-8 👍 Doing at time 35.999999999999986
#  Relative error = 1.6945437914086075e-8 👍 Doing at time 35.999999999999986
#  Relative error = 8.22239554443425e-13 👍 Doing at time 35.999999999999986
#  Entering time step10:40.0
#  Relative error = 1.5614926835374283e-16 👍 Doing at time 39.999999999999986
#  Entering time step11:44.0
#  Relative error = 2.3640276936032493e-8 👍 Doing at time 43.999999999999986
#  Relative error = 3.1904101925426384e-8 👍 Doing at time 43.999999999999986
#  Relative error = 1.5184181391375612e-12 👍 Doing at time 43.999999999999986
#  Entering time step12:48.0
#  Relative error = 1.5469587064449404e-16 👍 Doing at time 47.999999999999986
#  Entering time step13:52.0
#  Relative error = 4.189789291135274e-8 👍 Doing at time 51.999999999999986
#  Relative error = 5.379198660831257e-8 👍 Doing at time 51.999999999999986
#  Relative error = 2.529797133496248e-12 👍 Doing at time 51.999999999999986
#  Entering time step14:56.0
#  Relative error = 1.593240105047525e-16 👍 Doing at time 55.999999999999986
#  Entering time step15:60.0
#  Relative error = 6.774424023785519e-8 👍 Doing at time 59.999999999999986
#  Relative error = 8.392869308335242e-8 👍 Doing at time 59.999999999999986
#  Relative error = 3.927683559731542e-12 👍 Doing at time 59.999999999999986
#  Entering time step16:64.0
#  Relative error = 1.574976862520648e-16 👍 Doing at time 63.999999999999986
#  Entering time step17:68.0
#  Relative error = 1.0249873209918797e-7 👍 Doing at time 68.00000000000006
#  Relative error = 1.2363355705048673e-7 👍 Doing at time 68.00000000000006
#  Relative error = 5.81371968732853e-12 👍 Doing at time 68.00000000000006
#  Entering time step18:72.0
#  Relative error = 1.5977324806455843e-16 👍 Doing at time 72.00000000000006
#  Entering time step19:76.0
#  Relative error = 1.4748041563287543e-7 👍 Doing at time 76.00000000000006
#  Relative error = 1.742254968879674e-7 👍 Doing at time 76.00000000000006
#  Relative error = 8.367904594149926e-12 👍 Doing at time 76.00000000000006
#  Entering time step20:80.0
#  Relative error = 6.148198687559929e-17 👍 Doing at time 80.00000000000006
#  Entering time step21:84.0
#  Relative error = 2.0400774787900682e-7 👍 Doing at time 84.00000000000006
#  Relative error = 2.3702281195513047e-7 👍 Doing at time 84.00000000000006
#  Relative error = 1.1952477694221777e-11 👍 Doing at time 84.00000000000006
#  Entering time step22:88.0
#  Relative error = 2.6250455887840495e-16 👍 Doing at time 88.00000000000006
#  Entering time step23:92.0
#  Relative error = 2.7339826230201965e-7 👍 Doing at time 92.00000000000006
#  Relative error = 3.1334292411233467e-7 👍 Doing at time 92.00000000000006
#  Relative error = 1.7285512493417177e-11 👍 Doing at time 92.00000000000006
#  Entering time step24:96.0
#  Relative error = 1.1350613244581317e-15 👍 Doing at time 96.00000000000006
#  Entering time step25:100.0
#  Relative error = 3.5696810530990925e-7 👍 Doing at time 100.00000000000006
#  Relative error = 4.045020554758688e-7 👍 Doing at time 100.00000000000006
#  Relative error = 2.5580838940847213e-11 👍 Doing at time 100.00000000000006
#  Entering time step26:104.0
#  Relative error = 3.199353905723561e-15 👍 Doing at time 104.00000000000006
#  Entering time step27:108.0
#  Relative error = 4.5603153828550993e-7 👍 Doing at time 108.00000000000006
#  Relative error = 5.11814835022482e-7 👍 Doing at time 108.00000000000006
#  Relative error = 3.845878282823957e-11 👍 Doing at time 108.00000000000006
#  Entering time step28:112.0
#  Relative error = 7.744584059548131e-15 👍 Doing at time 112.00000000000006
#  Entering time step29:116.0
#  Relative error = 5.719005935472728e-7 👍 Doing at time 116.00000000000006
#  Relative error = 6.365938268874628e-7 👍 Doing at time 116.00000000000006
#  Relative error = 5.796290664668518e-11 👍 Doing at time 116.00000000000006
#  Entering time step30:120.0
#  Relative error = 1.7096494579844696e-14 👍 Doing at time 120.00000000000006
#  Entering time step31:124.0
#  Relative error = 7.058845409958402e-7 👍 Doing at time 124.00000000000006
#  Relative error = 7.801489733161296e-7 👍 Doing at time 124.00000000000006
#  Relative error = 8.679499348553426e-11 👍 Doing at time 124.00000000000006
#  Entering time step32:128.0
#  Relative error = 3.549123484229805e-14 👍 Doing at time 128.00000000000006
#  Entering time step33:132.0
#  Relative error = 8.592890458786036e-7 👍 Doing at time 132.00000000000006
#  Relative error = 9.437869444047503e-7 👍 Doing at time 132.00000000000006
#  Relative error = 1.2852457040936639e-10 👍 Doing at time 132.00000000000006
#  Entering time step34:136.0
#  Relative error = 7.022928483062389e-14 👍 Doing at time 136.00000000000006
#  Entering time step35:140.0
#  Relative error = 1.0334152524275356e-6 👍 Doing at time 140.00000000000006
#  Relative error = 1.128810387632974e-6 👍 Doing at time 140.00000000000006
#  Relative error = 1.8777641633307862e-10 👍 Doing at time 140.00000000000006
#  Entering time step36:144.0
#  Relative error = 1.3341513138435732e-13 👍 Doing at time 144.00000000000006
#  Entering time step37:148.0
#  Relative error = 1.229558781377742e-6 👍 Doing at time 148.00000000000006
#  Relative error = 1.336517069046367e-6 👍 Doing at time 148.00000000000006
#  Relative error = 2.704613437810541e-10 👍 Doing at time 148.00000000000006
#  Entering time step38:152.0
#  Relative error = 2.4469099230328303e-13 👍 Doing at time 152.00000000000006
#  Entering time step39:156.0
#  Relative error = 1.4490085673981424e-6 👍 Doing at time 156.00000000000006
#  Relative error = 1.5681988986832184e-6 👍 Doing at time 156.00000000000006
#  Relative error = 3.84017668044997e-10 👍 Doing at time 156.00000000000006
#  Entering time step40:160.0
#  Relative error = 4.3497991555369347e-13 👍 Doing at time 160.00000000000006
#  Entering time step41:164.0
#  Relative error = 1.693045558204582e-6 👍 Doing at time 164.00000000000006
#  Relative error = 1.8251408317888728e-6 👍 Doing at time 164.00000000000006
#  Relative error = 5.376824730020957e-10 👍 Doing at time 164.00000000000006
#  Entering time step42:168.0
#  Relative error = 7.519006601510771e-13 👍 Doing at time 168.00000000000006
#  Entering time step43:172.0
#  Relative error = 1.9629412462072522e-6 👍 Doing at time 172.00000000000006
#  Relative error = 2.1086196376282837e-6 👍 Doing at time 172.00000000000006
#  Relative error = 7.428369527998262e-10 👍 Doing at time 172.00000000000006
#  Entering time step44:176.0
#  Relative error = 1.2671990218093095e-12 👍 Doing at time 176.00000000000006
#  Entering time step45:180.0
#  Relative error = 2.2599559764731487e-6 👍 Doing at time 180.00000000000006
#  Relative error = 2.4199025272320496e-6 👍 Doing at time 180.00000000000006
#  Relative error = 1.0132988541215112e-9 👍 Doing at time 180.00000000000006
#  Entering time step46:184.0
#  Relative error = 2.0869133255715712e-12 👍 Doing at time 184.00000000000006
#  Entering time step47:188.0
#  Relative error = 2.585337144900226e-6 👍 Doing at time 188.00000000000006
#  Relative error = 2.760245630706549e-6 👍 Doing at time 188.00000000000006
#  Relative error = 1.3658032219542796e-9 👍 Doing at time 188.00000000000006
#  Entering time step48:192.0
#  Relative error = 3.365068197287142e-12 👍 Doing at time 192.00000000000006
#  Entering time step49:196.0
#  Relative error = 2.940317031491221e-6 👍 Doing at time 196.00000000000006
#  Relative error = 3.130892314794102e-6 👍 Doing at time 196.00000000000006
#  Relative error = 1.8203718864342476e-9 👍 Doing at time 196.00000000000006
#  Entering time step50:200.0
#  Relative error = 5.3217869758873596e-12 👍 Doing at time 200.00000000000006
#  Entering time step51:240.0
#  Relative error = 3.2917961844915282e-6 👍 Doing at time 240.0
#  Relative error = 5.911245792178053e-5 👍 Doing at time 240.0
#  Relative error = 3.277098695339926e-8 👍 Doing at time 240.0
#  Relative error = 3.9219143809040255e-11 👍 Doing at time 240.0
#  Entering time step52:280.0
#  Relative error = 6.916969597583809e-14 👍 Doing at time 280.0
#  Entering time step53:320.0
#  Relative error = 4.98831742664303e-5 👍 Doing at time 320.0
#  Relative error = 6.349605200129483e-5 👍 Doing at time 320.0
#  Relative error = 8.476197201857192e-8 👍 Doing at time 320.0
#  Relative error = 2.5142992352305434e-10 👍 Doing at time 320.0
#  Entering time step54:360.0
#  Relative error = 1.0591005690351904e-12 👍 Doing at time 360.0
#  Entering time step55:400.0
#  Relative error = 7.691598103113302e-5 👍 Doing at time 400.0
#  Relative error = 9.042020895152461e-5 👍 Doing at time 400.0
#  Relative error = 2.0374226369341198e-7 👍 Doing at time 400.0
#  Relative error = 1.1240317831126632e-9 👍 Doing at time 400.0
#  Entering time step56:440.0
#  Relative error = 9.024654561895605e-12 👍 Doing at time 440.0
#  Entering time step57:480.0
#  Relative error = 0.00010355840364301516 👍 Doing at time 480.0
#  Relative error = 0.00011707115749882174 👍 Doing at time 480.0
#  Relative error = 4.076009104812427e-7 👍 Doing at time 480.0
#  Relative error = 3.623258197933894e-9 👍 Doing at time 480.0
#  Entering time step58:520.0
#  Relative error = 4.7448262552849717e-11 👍 Doing at time 520.0
#  Entering time step59:560.0
#  Relative error = 0.00012992507260653062 👍 Doing at time 560.0
#  Relative error = 0.00014357645425751506 👍 Doing at time 560.0
#  Relative error = 7.170832397160619e-7 👍 Doing at time 560.0
#  Relative error = 9.370944991890011e-9 👍 Doing at time 560.0
#  Entering time step60:600.0
#  Relative error = 1.8319631619314284e-10 👍 Doing at time 600.0
#  Entering time step61:640.0
#  Relative error = 0.00015606852012849394 👍 Doing at time 640.0
#  Relative error = 0.00017000186605105167 👍 Doing at time 640.0
#  Relative error = 1.153348062375888e-6 👍 Doing at time 640.0
#  Relative error = 2.083255553309367e-8 👍 Doing at time 640.0
#  Relative error = 5.745894975767698e-10 👍 Doing at time 640.0
#  Entering time step62:680.0
#  Relative error = 3.179623872832223e-11 👍 Doing at time 680.0
#  Entering time step63:720.0
#  Relative error = 0.0001820224347745646 👍 Doing at time 720.0
#  Relative error = 0.0001964174110895255 👍 Doing at time 720.0
#  Relative error = 1.7343276812589293e-6 👍 Doing at time 720.0
#  Relative error = 4.1381148749121344e-8 👍 Doing at time 720.0
#  Relative error = 1.5515363280269767e-9 👍 Doing at time 720.0
#  Entering time step64:760.0
#  Relative error = 1.20216226326257e-10 👍 Doing at time 760.0
#  Entering time step65:800.0
#  Relative error = 0.00020778608574051474 👍 Doing at time 800.0
#  Relative error = 0.00022268789531930416 👍 Doing at time 800.0
#  Relative error = 2.4939856839130422e-6 👍 Doing at time 800.0
#  Relative error = 7.621898577373407e-8 👍 Doing at time 800.0
#  Relative error = 3.777496169120528e-9 👍 Doing at time 800.0
#  Entering time step66:840.0
#  Relative error = 3.9726324359665414e-10 👍 Doing at time 840.0
#  Entering time step67:880.0
#  Relative error = 0.00023316672873323327 👍 Doing at time 880.0
#  Relative error = 0.00024882249468358684 👍 Doing at time 880.0
#  Relative error = 3.4618395093782236e-6 👍 Doing at time 880.0
#  Relative error = 1.3241019666397018e-7 👍 Doing at time 880.0
#  Relative error = 8.532326792318526e-9 👍 Doing at time 880.0
#  Entering time step68:920.0
#  Relative error = 1.1894443611505625e-9 👍 Doing at time 920.0
#  Entering time step69:960.0
#  Relative error = 0.0002581855044601821 👍 Doing at time 960.0
#  Relative error = 0.00027485200861145586 👍 Doing at time 960.0
#  Relative error = 4.660683325723005e-6 👍 Doing at time 960.0
#  Relative error = 2.1888209313395763e-7 👍 Doing at time 960.0
#  Relative error = 1.8221578725450163e-8 👍 Doing at time 960.0
#  Relative error = 3.2966231518905535e-9 👍 Doing at time 960.0
#  Entering time step70:1000.0
#  Relative error = 6.317594805626397e-10 👍 Doing at time 1000.0
#  Entering time step71:1040.0
#  Relative error = 0.00028276727020826094 👍 Doing at time 1040.0
#  Relative error = 0.0003007029904237789 👍 Doing at time 1040.0
#  Relative error = 6.119739929387541e-6 👍 Doing at time 1040.0
#  Relative error = 3.474641502264692e-7 👍 Doing at time 1040.0
#  Relative error = 3.7561477572121354e-8 👍 Doing at time 1040.0
#  Relative error = 8.625951953582525e-9 👍 Doing at time 1040.0
#  Entering time step72:1080.0
#  Relative error = 7.060035189534199e-7 👍 Doing at time 1520.0
#  Relative error = 6.414227601387281e-7 👍 Doing at time 1520.0
#  Relative error = 5.854002913954358e-7 👍 Doing at time 1520.0
#  Relative error = 5.364409951952397e-7 👍 Doing at time 1520.0
#  Entering time step84:1560.0
#  Relative error = 4.934205539682526e-7 👍 Doing at time 1560.0
#  Relative error = 0.00038623947936069076 👍 Doing at time 1560.0
#  Relative error = 1.788941014992892e-5 👍 Doing at time 1560.0
#  Relative error = 3.916802698025969e-6 👍 Doing at time 1560.0
#  Relative error = 3.6882661295051596e-6 👍 Doing at time 1560.0
#  Relative error = 3.6337363349274815e-6 👍 Doing at time 1560.0
#  Relative error = 3.67992079248745e-6 👍 Doing at time 1560.0
#  Relative error = 3.770777728099625e-6 👍 Doing at time 1560.0
#  Relative error = 3.896356559046065e-6 👍 Doing at time 1560.0
#  Relative error = 4.049035267585363e-6 👍 Doing at time 1560.0
#  Relative error = 4.218563621288068e-6 👍 Doing at time 1560.0
#  Relative error = 4.392405048936857e-6 👍 Doing at time 1560.0
#  Relative error = 4.55374090744454e-6 👍 Doing at time 1560.0
#  Relative error = 4.680850093422037e-6 👍 Doing at time 1560.0
#  Relative error = 4.749010272722452e-6 👍 Doing at time 1560.0
#  Relative error = 4.7335456195075575e-6 👍 Doing at time 1560.0
#  Entering time step85:1600.0
#  Relative error = 4.6150028899734624e-6 👍 Doing at time 1600.0
#  Relative error = 0.00018374688857717656 👍 Doing at time 1600.0
#  Relative error = 8.755767228978549e-6 👍 Doing at time 1600.0
#  Relative error = 6.604923190465257e-6 👍 Doing at time 1600.0
#  Relative error = 5.2754134658897e-6 👍 Doing at time 1600.0
#  Relative error = 4.070702448867684e-6 👍 Doing at time 1600.0
#  Relative error = 3.044076729862597e-6 👍 Doing at time 1600.0
#  Relative error = 2.219884721308766e-6 👍 Doing at time 1600.0
#  Relative error = 1.589098875621811e-6 👍 Doing at time 1600.0
#  Relative error = 1.1226041746606937e-6 👍 Doing at time 1600.0
#  Relative error = 7.856940157695167e-7 👍 Doing at time 1600.0
#  Relative error = 5.463603255996117e-7 👍 Doing at time 1600.0
#  Relative error = 3.782568214002421e-7 👍 Doing at time 1600.0
#  Relative error = 2.610452127970735e-7 👍 Doing at time 1600.0
#  Relative error = 1.797693327698152e-7 👍 Doing at time 1600.0
#  Relative error = 1.236164543884129e-7 👍 Doing at time 1600.0
#  Entering time step86:1640.0
#  Relative error = 8.491760612006784e-8 👍 Doing at time 1640.0
#  Relative error = 0.0001896798042610282 👍 Doing at time 1640.0
#  Relative error = 4.440287116630759e-6 👍 Doing at time 1640.0
#  Relative error = 1.719950356357293e-6 👍 Doing at time 1640.0
#  Relative error = 1.0365548511509571e-6 👍 Doing at time 1640.0
#  Relative error = 6.474420230634655e-7 👍 Doing at time 1640.0
#  Relative error = 4.1106494286376016e-7 👍 Doing at time 1640.0
#  Relative error = 1.976312772358286e-5 👍 Doing at time 1880.0
#  Relative error = 2.496617859260518e-6 👍 Doing at time 1880.0
#  Relative error = 1.4546047947173302e-6 👍 Doing at time 1880.0
#  Relative error = 8.49701393571059e-7 👍 Doing at time 1880.0
#  Relative error = 4.963906780554992e-7 👍 Doing at time 1880.0
#  Relative error = 2.9013420246755336e-7 👍 Doing at time 1880.0
#  Relative error = 1.696228788762204e-7 👍 Doing at time 1880.0
#  Relative error = 9.919463694516743e-8 👍 Doing at time 1880.0
#  Relative error = 5.8018485886544695e-8 👍 Doing at time 1880.0
#  Relative error = 3.3941478385974815e-8 👍 Doing at time 1880.0
#  Relative error = 1.9858144358837323e-8 👍 Doing at time 1880.0
#  Relative error = 1.1620065288949957e-8 👍 Doing at time 1880.0
#  Relative error = 6.7999497278045226e-9 👍 Doing at time 1880.0
#  Entering time step93:1920.0
#  Relative error = 3.979667109941585e-9 👍 Doing at time 1920.0
#  Entering time step94:1960.0
#  Relative error = 0.0003877018447415317 👍 Doing at time 1960.0
#  Relative error = 0.0004888966638838582 👍 Doing at time 1960.0
#  Relative error = 2.3157092539570156e-5 👍 Doing at time 1960.0
#  Relative error = 2.995922581202587e-6 👍 Doing at time 1960.0
#  Relative error = 1.8790853199161275e-6 👍 Doing at time 1960.0
#  Relative error = 1.181197657184161e-6 👍 Doing at time 1960.0
#  Relative error = 7.431210064875267e-7 👍 Doing at time 1960.0
#  Relative error = 4.681916496577468e-7 👍 Doing at time 1960.0
#  Relative error = 2.9551217062834615e-7 👍 Doing at time 1960.0
#  Relative error = 1.867550367587723e-7 👍 Doing at time 1960.0
#  Relative error = 1.1812158846433387e-7 👍 Doing at time 1960.0
#  Relative error = 7.47657604513446e-8 👍 Doing at time 1960.0
#  Relative error = 4.735314054899717e-8 👍 Doing at time 1960.0
#  Relative error = 3.000463220714061e-8 👍 Doing at time 1960.0
#  Relative error = 1.9020412862828825e-8 👍 Doing at time 1960.0
#  Relative error = 1.2061019421558715e-8 👍 Doing at time 1960.0
#  Entering time step95:2000.0
#  Relative error = 7.650068265654764e-9 👍 Doing at time 2000.0
#  Entering time step96:2040.0
#  Relative error = 0.00039189679376628537 👍 Doing at time 2040.0
#  Relative error = 0.0005030698709657986 👍 Doing at time 2040.0
#  Relative error = 2.7225542172167185e-5 👍 Doing at time 2040.0
#  Relative error = 3.856002564488737e-6 👍 Doing at time 2040.0
#  Relative error = 2.6364430761447396e-6 👍 Doing at time 2040.0
#  Relative error = 1.847505638661294e-6 👍 Doing at time 2040.0
#  Relative error = 1.3063763279160692e-6 👍 Doing at time 2040.0
#  Relative error = 9.326488843486661e-7 👍 Doing at time 2040.0
#  Relative error = 6.717946355684369e-7 👍 Doing at time 2040.0
#  Relative error = 4.876718663290623e-7 👍 Doing at time 2040.0
#  Relative error = 3.563490344576286e-7 👍 Doing at time 2040.0
#  Relative error = 2.618521255652936e-7 👍 Doing at time 2040.0
#  Relative error = 1.9327152955871267e-7 👍 Doing at time 2040.0
#  Relative error = 1.4319380597095017e-7 👍 Doing at time 2040.0
#  Relative error = 1.0641566869438949e-7 👍 Doing at time 2040.0
#  Relative error = 7.928349285956732e-8 👍 Doing at time 2040.0
#  Entering time step97:2080.0
#  Relative error = 5.918530162476607e-8 👍 Doing at time 2080.0
#  Relative error = 0.0003934524586642523 👍 Doing at time 2080.0
#  Relative error = 2.5528560694555323e-5 👍 Doing at time 2080.0
#  Relative error = 3.7096018506196594e-6 👍 Doing at time 2080.0
#  Relative error = 2.079296311261637e-6 👍 Doing at time 2080.0
#  Relative error = 1.6034924028588314e-6 👍 Doing at time 2080.0
#  Relative error = 1.2519603678691726e-6 👍 Doing at time 2080.0
#  Relative error = 9.903377072267312e-7 👍 Doing at time 2080.0
#  Relative error = 7.926518584028725e-7 👍 Doing at time 2080.0
#  Relative error = 6.406418172449744e-7 👍 Doing at time 2080.0
#  Relative error = 5.218239765296999e-7 👍 Doing at time 2080.0
#  Relative error = 4.2777739026981466e-7 👍 Doing at time 2080.0
#  Relative error = 3.524358451754641e-7 👍 Doing at time 2080.0
#  Relative error = 2.9151402580117467e-7 👍 Doing at time 2080.0
#  Relative error = 2.4201820696811625e-7 👍 Doing at time 2080.0
#  Relative error = 2.0180721554645112e-7 👍 Doing at time 2080.0
#  Entering time step98:2120.0
#  Relative error = 1.6877069042700266e-7 👍 Doing at time 2120.0
#  Relative error = 0.00044210537863095025 👍 Doing at time 2120.0
#  Relative error = 2.9041954026261265e-5 👍 Doing at time 2120.0
#  Relative error = 4.600854793781881e-6 👍 Doing at time 2120.0
#  Relative error = 2.6839660020778218e-6 👍 Doing at time 2120.0
#  Relative error = 2.295156871851136e-6 👍 Doing at time 2120.0
#  Relative error = 2.002192253142024e-6 👍 Doing at time 2120.0
#  Relative error = 1.7802906714619697e-6 👍 Doing at time 2120.0
#  Relative error = 1.609109582265019e-6 👍 Doing at time 2120.0
#  Relative error = 1.4739952477283666e-6 👍 Doing at time 2120.0
#  Relative error = 1.365204763449524e-6 👍 Doing at time 2120.0
#  Relative error = 1.2771728273286249e-6 👍 Doing at time 2120.0
#  Relative error = 1.206354653976983e-6 👍 Doing at time 2120.0
#  Relative error = 1.1478358284907378e-6 👍 Doing at time 2120.0
#  Relative error = 1.097774844459215e-6 👍 Doing at time 2120.0
#  Relative error = 1.0550704221851361e-6 👍 Doing at time 2120.0
#  Entering time step99:2160.0
#  Relative error = 1.0179554766715939e-6 👍 Doing at time 2160.0
#  Relative error = 0.0004411421495537428 👍 Doing at time 2160.0
#  Relative error = 3.112809172326314e-5 👍 Doing at time 2160.0
#  Relative error = 6.389443602351518e-6 👍 Doing at time 2160.0
#  Relative error = 4.647548021005475e-6 👍 Doing at time 2160.0
#  Relative error = 4.703993839646897e-6 👍 Doing at time 2160.0
#  Relative error = 4.906709351340367e-6 👍 Doing at time 2160.0
#  Relative error = 5.257922120857879e-6 👍 Doing at time 2160.0
#  Relative error = 5.767680455043771e-6 👍 Doing at time 2160.0
#  Relative error = 6.419200976013472e-6 👍 Doing at time 2160.0
#  Relative error = 7.217055202470702e-6 👍 Doing at time 2160.0
#  Relative error = 8.201976359684894e-6 👍 Doing at time 2160.0
#  Relative error = 9.434460749731894e-6 👍 Doing at time 2160.0
#  Relative error = 1.097650300002584e-5 👍 Doing at time 2160.0
#  Relative error = 1.2886657489805176e-5 👍 Doing at time 2160.0
#  Relative error = 1.5137183503956172e-5 👍 Doing at time 2160.0
#  Entering time step100:2200.0
#  Relative error = 1.77210420600574e-5 👍 Doing at time 2200.0
#  Relative error = 0.00041723512043136314 👍 Doing at time 2200.0
#  Relative error = 4.523368492968313e-5 👍 Doing at time 2200.0
#  Relative error = 2.986475981980268e-5 👍 Doing at time 2200.0
#  Relative error = 3.2611064002472914e-5 👍 Doing at time 2200.0
#  Relative error = 3.453194311769259e-5 👍 Doing at time 2200.0
#  Relative error = 3.579086065951831e-5 👍 Doing at time 2200.0
#  Relative error = 3.683684834288036e-5 👍 Doing at time 2200.0
#  Relative error = 3.788936590994007e-5 👍 Doing at time 2200.0
#  Relative error = 3.8973860377697975e-5 👍 Doing at time 2200.0
#  Relative error = 4.017513575180311e-5 👍 Doing at time 2200.0
#  Relative error = 4.146899559675372e-5 👍 Doing at time 2200.0
#  Relative error = 4.286214674238128e-5 👍 Doing at time 2200.0
#  Relative error = 4.4402170551797626e-5 👍 Doing at time 2200.0
#  Relative error = 4.609044636532951e-5 👍 Doing at time 2200.0
#  Relative error = 4.790992491409867e-5 👍 Doing at time 2200.0
#  Entering time step101:2240.0
#  Relative error = 4.988461339794194e-5 👍 Doing at time 2240.0
#  Relative error = 0.00028693788614828677 👍 Doing at time 2240.0
#  Relative error = 6.657623352245889e-5 👍 Doing at time 2240.0
#  Relative error = 6.666989553479496e-5 👍 Doing at time 2240.0
#  Relative error = 7.022122549978652e-5 👍 Doing at time 2240.0
#  Relative error = 7.379973867237576e-5 👍 Doing at time 2240.0
#  Relative error = 7.771479228131835e-5 👍 Doing at time 2240.0
#  Relative error = 8.204568186800756e-5 👍 Doing at time 2240.0
#  Relative error = 8.669048447137603e-5 👍 Doing at time 2240.0
#  Relative error = 9.169356651906251e-5 👍 Doing at time 2240.0
#  Relative error = 9.699525549449191e-5 👍 Doing at time 2240.0
#  Relative error = 0.00010276681463622854 👍 Doing at time 2240.0
#  Relative error = 0.00010901453779693022 👍 Doing at time 2240.0
#  Relative error = 0.00011567685934422337 👍 Doing at time 2240.0
#  Relative error = 0.00012293650536287975 👍 Doing at time 2240.0
#  Relative error = 0.00013063644268256812 👍 Doing at time 2240.0
#  Entering time step102:2280.0
#  Relative error = 0.00013882605899713637 👍 Doing at time 2280.0
#  Relative error = 0.00030599273884302576 👍 Doing at time 2280.0
#  Relative error = 0.0001821894781349563 👍 Doing at time 2280.0
#  Relative error = 0.0006975285135908832 👍 Doing at time 2400.0
#  Relative error = 0.0006482517184560877 👍 Doing at time 2400.0
#  Relative error = 0.00062579739322401 👍 Doing at time 2400.0
#  Relative error = 0.0006075227476843491 👍 Doing at time 2400.0
#  Relative error = 0.0005921275893634241 👍 Doing at time 2400.0
#  Relative error = 0.0005790087403316092 👍 Doing at time 2400.0
#  Relative error = 0.0005679959042464327 👍 Doing at time 2400.0
#  Relative error = 0.0005587935087262532 👍 Doing at time 2400.0
#  Relative error = 0.0005510992538807992 👍 Doing at time 2400.0
#  Relative error = 0.0005483074667729982 👍 Doing at time 2400.0
#  Relative error = 0.0005480928290436428 👍 Doing at time 2400.0
#  Relative error = 0.0005532796499394251 👍 Doing at time 2400.0
#  Relative error = 0.0005660153813992173 👍 Doing at time 2400.0
#  Relative error = 0.0005920418227238565 👍 Doing at time 2400.0
#  Relative error = 0.0006400875579310625 👍 Doing at time 2400.0
#  Entering time step106:2440.0
#  Relative error = 0.0007371745303929413 👍 Doing at time 2440.0
#  Relative error = 0.001029836666944883 👍 Doing at time 2440.0
#  Relative error = 0.001756002840146152 👍 Doing at time 2440.0
#  Relative error = 0.0029177104131208813 👍 Doing at time 2440.0
#  Relative error = 0.0008371078211324939 👍 Doing at time 2440.0
#  Relative error = 0.0004627866849016652 👍 Doing at time 2440.0
#  Relative error = 0.00044960823085387757 👍 Doing at time 2440.0
#  Relative error = 0.000497160423153503 👍 Doing at time 2440.0
#  Relative error = 0.00048139978365636737 👍 Doing at time 2440.0
#  Relative error = 0.00035416995427298603 👍 Doing at time 2440.0
#  Relative error = 0.00020338966533647426 👍 Doing at time 2440.0
#  Relative error = 9.105569929803125e-5 👍 Doing at time 2440.0
#  Relative error = 2.9248109777350498e-5 👍 Doing at time 2440.0
#  Relative error = 2.8374481148060984e-6 👍 Doing at time 2440.0
#  Relative error = 1.6436069935557566e-8 👍 Doing at time 2440.0
#  Relative error = 1.968865252865622e-10 👍 Doing at time 2440.0
#  Entering time step107:2480.0
#  Relative error = 7.0310047344477255e-12 👍 Doing at time 2480.0
#  Entering time step108:2520.0
#  Relative error = 5.679009157347429e-10 👍 Doing at time 2520.0
#  Entering time step109:2560.0
#  Relative error = 9.540130409178222e-10 👍 Doing at time 2560.0
#  Entering time step110:2600.0
#  Relative error = 1.624187522217422e-9 👍 Doing at time 2600.0
#  Entering time step111:2640.0
#  Relative error = 1.4232827413489695e-9 👍 Doing at time 2640.0
#  Entering time step112:2680.0
#  Relative error = 1.5315982891517271e-9 👍 Doing at time 2680.0
#  Entering time step113:2720.0
#  Relative error = 1.5931791106040654e-9 👍 Doing at time 2720.0
#  Entering time step114:2760.0
#  Relative error = 1.775433416996201e-9 👍 Doing at time 2760.0
#  Entering time step115:2800.0
#  Relative error = 1.8680586013334985e-9 👍 Doing at time 2800.0

# %%
plot(Displacement[1:end],Load[1:end].*1e-3, xlabel = "mm", ylabel = "kN")
